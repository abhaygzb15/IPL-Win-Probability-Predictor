# %%
import pandas as pd
import numpy as np

# %%
matches=pd.read_csv('matches.csv')
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.shape
# Out:
# (756, 18)

# %%
deliveries=pd.read_csv('deliveries.csv')
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
total_score_df=deliveries.groupby(['match_id','inning'])['total_runs'].sum().reset_index()
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
total_score_df=total_score_df[total_score_df['inning']==1]
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
matches_df=matches.merge(total_score_df[['match_id','total_runs']],left_on='id',right_on='match_id')
matches_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
matches_df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'match_id', 'total_runs'],
#       dtype='object')

# %%
matches_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
teams=['Sunrisers Hyderabad', 
       'Mumbai Indians',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders', 
       'Kings XI Punjab',
       'Chennai Super Kings', 
       'Rajasthan Royals', 
       'Delhi Capitals']

# %%
matches_df['team1']=matches_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
matches_df['team2']=matches_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')
matches_df['team1']=matches_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
matches_df['team2']=matches_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
matches_df=matches_df[matches_df['team1'].isin(teams)]
matches_df=matches_df[matches_df['team2'].isin(teams)]
# isin used to take only those rows who have teamnames in team for team1.

# %%
matches_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
matches_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals'],
#       dtype=object)

# %%
matches_df.dl_applied.value_counts()
# Out:
# dl_applied
# 0    626
# 1     15
# Name: count, dtype: int64

# %%
matches_df=matches_df[matches_df['dl_applied']==0]
matches_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
matches_df=matches_df[['match_id','city','winner','total_runs']]
matches_df
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         207
# 4           5      Bangalore  Royal Challengers Bangalore         157
# 6           7         Mumbai               Mumbai Indians         178
# 7           8         Indore              Kings XI Punjab         148
# 9          10         Mumbai               Mumbai Indians         158
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         143
# 752     11412        Chennai               Mumbai Indians         136
# 753     11413  Visakhapatnam               Delhi Capitals         171
# 754     11414  Visakhapatnam          Chennai Super Kings         155
# 755     11415      Hyderabad               Mumbai Indians         152
#
# [626 rows x 4 columns]

# %%
deliveries_df=matches_df.merge(deliveries,on='match_id')
deliveries_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
deliveries_df=deliveries_df[deliveries_df['inning']==2]
deliveries_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries_df['current_score']=deliveries_df.groupby(['match_id'])['total_runs_y'].cumsum()
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\1690849589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['current_score']=deliveries_df.groupby(['match_id'])['total_runs_y'].cumsum()

# %%
deliveries_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries_df['runs_left']=deliveries_df['total_runs_x']-deliveries_df['current_score']
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\245662547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['runs_left']=deliveries_df['total_runs_x']-deliveries_df['current_score']
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
deliveries_df['balls_left']=126-(deliveries_df['over']*6 + deliveries_df['ball'])
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\225837914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['balls_left']=126-(deliveries_df['over']*6 + deliveries_df['ball'])
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].fillna("0")
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\3627536954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].fillna("0")
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\873191999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].astype('int')
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\193221970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].astype('int')

# %%
wickets=deliveries_df.groupby(['match_id'])['player_dismissed'].cumsum().values
wickets
# Out:
# array([0, 0, 0, ..., 6, 6, 7])

# %%
deliveries_df['wickets']=10-wickets
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\2877089977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['wickets']=10-wickets
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# ...

# %%
deliveries_df.head(10)
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
# 130         1  Hyderabad  Sunrisers Hyderabad           207       2
# 131         1  Hyderabad  Sunrisers Hyderabad           207       2
# 132         1  Hyderabad  Sunrisers Hyderabad           207       2
# 133         1  Hyderabad  Sunrisers Hyderabad           207       2
# 134         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# ...

# %%
deliveries_df['crr']=(deliveries_df['current_score']/(120-deliveries_df['balls_left']))*6
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\4232349758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['crr']=(deliveries_df['current_score']/(120-deliveries_df['balls_left']))*6
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
deliveries_df['rrr']=(deliveries_df['runs_left']/deliveries_df['balls_left'])*6
deliveries_df
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\536335007.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['rrr']=(deliveries_df['runs_left']/deliveries_df['balls_left'])*6
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# ...

# %%
def result(row):
    if(row['winner']==row['batting_team']):
        return 1
    else:
        return 0
deliveries_df['result']=deliveries_df.apply(result,axis=1)
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\1323274670.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   deliveries_df['result']=deliveries_df.apply(result,axis=1)

# %%
deliveries_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
final_df=deliveries_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]
final_df
# Out:
#                        batting_team         bowling_team       city  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 126     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 127     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 128     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# 129     Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad
# ...                             ...                  ...        ...
# 149573          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149574          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149575          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149576          Chennai Super Kings       Mumbai Indians  Hyderabad
# 149577          Chennai Super Kings       Mumbai Indians  Hyderabad
#
#         runs_left  balls_left  wickets  total_runs_x       crr        rrr  \
# 125           206         119       10           207  6.000000  10.386555
# ...

# %%
final_df.dropna(inplace=True)
# Out:
# C:\Users\ABHAY\AppData\Local\Temp\ipykernel_24128\2709626079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
final_df.isna().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df.describe()
# Out:
#           runs_left   balls_left       wickets  total_runs_x           crr  \
# count  71574.000000  71574.00000  71574.000000  71574.000000  71574.000000
# mean      92.385824     62.67491      7.538128    165.767541      7.449289
# std       50.057328     33.39732      2.139379     29.290992      2.277963
# min      -16.000000     -2.00000      0.000000     65.000000      0.000000
# 25%       53.000000     35.00000      6.000000    147.000000      6.272727
# 50%       92.000000     63.00000      8.000000    165.000000      7.500000
# 75%      130.000000     92.00000      9.000000    185.000000      8.696629
# max      249.000000    119.00000     10.000000    250.000000     42.000000
#
#                 rrr        result
# count  7.157400e+04  71574.000000
# mean            NaN      0.525261
# std             NaN      0.499365
# min            -inf      0.000000
# 25%    7.156627e+00      0.000000
# 50%    8.888889e+00      1.000000
# 75%    1.092264e+01      1.000000
# ...

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
final_df.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  71342.000000  71342.000000  71342.000000  71342.000000  71342.000000
# mean      92.621065     62.878725      7.553251    165.726963      7.447791
# std       49.957572     33.259471      2.124334     29.294967      2.280498
# min      -16.000000     -2.000000      0.000000     65.000000      0.000000
# 25%       53.000000     35.000000      6.000000    147.000000      6.265782
# 50%       92.000000     64.000000      8.000000    165.000000      7.500000
# 75%      130.000000     92.000000      9.000000    185.000000      8.696385
# max      249.000000    119.000000     10.000000    250.000000     42.000000
#
#                 rrr        result
# count  71342.000000  71342.000000
# mean      10.368308      0.526646
# std       13.726365      0.499293
# min     -510.000000      0.000000
# 25%        7.151515      0.000000
# 50%        8.880000      1.000000
# 75%       10.894737      1.000000
# ...

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#           batting_team      bowling_team   city  runs_left  balls_left  \
# 97094  Kings XI Punjab  Delhi Daredevils  Delhi        109          90
#
#        wickets  total_runs_x   crr       rrr  result
# 97094       10           164  11.0  7.266667       1

# %%
final_df
# Out:
#                  batting_team                 bowling_team          city  \
# 33974        Delhi Daredevils              Kings XI Punjab    Chandigarh
# 113521       Rajasthan Royals  Royal Challengers Bangalore          Pune
# 138856    Chennai Super Kings               Mumbai Indians        Mumbai
# 38173          Mumbai Indians          Chennai Super Kings        Mumbai
# 66124         Kings XI Punjab  Royal Challengers Bangalore     Bangalore
# ...                       ...                          ...           ...
# 42770        Delhi Daredevils        Kolkata Knight Riders       Kolkata
# 85773          Mumbai Indians          Chennai Super Kings         Delhi
# 30058         Kings XI Punjab             Delhi Daredevils  Bloemfontein
# 12193   Kolkata Knight Riders              Kings XI Punjab    Chandigarh
# 62729        Delhi Daredevils              Deccan Chargers     Hyderabad
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=final_df.iloc[:,:-1]
Y=final_df.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=1)
X_train
# Out:
#                  batting_team                 bowling_team           city  \
# 84775         Kings XI Punjab  Royal Challengers Bangalore     Chandigarh
# 104320  Kolkata Knight Riders              Kings XI Punjab           Pune
# 114273  Kolkata Knight Riders             Delhi Daredevils        Kolkata
# 37161     Chennai Super Kings              Kings XI Punjab        Chennai
# 35238   Kolkata Knight Riders          Chennai Super Kings        Kolkata
# ...                       ...                          ...            ...
# 28401        Delhi Daredevils        Kolkata Knight Riders   Johannesburg
# 118486         Mumbai Indians          Sunrisers Hyderabad  Visakhapatnam
# 39639   Kolkata Knight Riders             Delhi Daredevils          Delhi
# 145376        Kings XI Punjab  Royal Challengers Bangalore      Bengaluru
# 57294          Mumbai Indians        Kolkata Knight Riders        Kolkata
#
#         runs_left  balls_left  wickets  total_runs_x        crr        rrr
# ...

# %%
X_test
# Out:
#                        batting_team                 bowling_team        city  \
# 146327  Royal Challengers Bangalore               Delhi Capitals       Delhi
# 141459               Delhi Capitals        Kolkata Knight Riders     Kolkata
# 24942               Kings XI Punjab  Royal Challengers Bangalore      Durban
# 50103   Royal Challengers Bangalore          Chennai Super Kings     Chennai
# 4011                Kings XI Punjab          Sunrisers Hyderabad  Chandigarh
# ...                             ...                          ...         ...
# 116654          Sunrisers Hyderabad              Kings XI Punjab   Hyderabad
# 57333                Mumbai Indians        Kolkata Knight Riders     Kolkata
# 102841             Rajasthan Royals               Mumbai Indians   Ahmedabad
# 14687               Deccan Chargers        Kolkata Knight Riders   Hyderabad
# 134221          Chennai Super Kings              Kings XI Punjab        Pune
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
trf=ColumnTransformer([('trf',OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team','city'])],remainder=
                     'passthrough')

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_predicted=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(Y_test,y_predicted))
# Out:
# 0.8039806573691218

# %%
pipe.score(X_test,Y_test)
# Out:
# 0.8039806573691218

# %%
# x_df is delivery dataset
def match_progression(x_df,match_id,pipe):
    
    # take out match data for every 6 ball
    match=x_df[x_df['match_id']==match_id]
    match=match[match['ball']==6]
    
    # ignore the after balls 120
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr']].dropna()
    temp_df=temp_df[temp_df['balls_left']!=0]
    
    # prediction and t(0) is 1st prob 
    result=pipe.predict_proba(temp_df)
    temp_df['lose']=np.round(result.T[0]*100,1)
    temp_df['win']=np.round(result.T[1]*100,1)
    temp_df['end_of_over']=range(1,temp_df.shape[0]+1)
    
    # take first value from list of target written repeatedly(120 times)
    target=temp_df['total_runs_x'].values[0]
    
    # list of runs left and copy to new runs
    # calculate runs made by run req now - run req prev
    runs=list(temp_df['runs_left'].values)
    new_runs=runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over']=np.array(runs)[:-1]-np.array(new_runs)
   
    # same like runs
    wickets=list(temp_df['wickets'].values)
    new_wickets=wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w=np.array(wickets)
    nw=np.array(new_wickets)
    temp_df['wickets_in_over']=(nw-w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target=match_progression(deliveries_df,75,pipe)
temp_df
# Out:
# Target- 137
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 10708            1                2                0  11.2  88.8
# 10716            2               14                0   6.0  94.0
# 10722            3                1                1  13.9  86.1
# 10729            4                8                1  19.9  80.1
# 10735            5                4                1  33.3  66.7
# 10741            6                9                0  27.9  72.1
# 10747            7                5                0  28.0  72.0
# 10753            8                4                0  29.4  70.6
# 10759            9               16                0  17.2  82.8
# 10766           10                6                0  16.3  83.7
# 10773           11                6                0  15.5  84.5
# 10779           12               15                0   8.8  91.2
# 10785           13                8                0   7.4  92.6
# ...

# %%
deliveries_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
deliveries_df['total_runs_x'].tail()
# Out:
# 149573    152
# 149574    152
# 149575    152
# 149576    152
# 149577    152
# Name: total_runs_x, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over']*10,color='orange',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target - '+str(target),size=20)
plt.show()

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
deliveries_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle

# %%
with open('pipe.pkl','wb') as F:
    pickle.dump(pipe,F)

# %%
pip install nbconvert==5.4.1
# Out:
# ...
#    ---------------------------------------- 0.0/407.8 kB ? eta -:--:--
#    --------------------------- ------------ 276.5/407.8 kB 8.6 MB/s eta 0:00:01
#    ---------------------------------------- 407.8/407.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/83.9 kB ? eta -:--:--
#    ---------------------------------------- 83.9/83.9 kB ? eta 0:00:00
# ...
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.5.4
#     Uninstalling nbconvert-6.5.4:
#       Successfully uninstalled nbconvert-6.5.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.23.4 requires nbconvert>=6.4.4, but you have nbconvert 5.4.1 which is incompatible.
